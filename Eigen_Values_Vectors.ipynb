# %%
import numpy as np

# %%
m = np.array([[1, 2], [3, 4]])
print("Matrix m:")
# Out:
# Matrix m:

# %%
w , v = np.linalg.eig(m)
print("Eigen values of m:")
print(w)
print("Eigen vectors of m:")
print(v)
# Out:
# Eigen values of m:
# [-0.37228132  5.37228132]
# Eigen vectors of m:
# [[-0.82456484 -0.41597356]
#  [ 0.56576746 -0.90937671]]
